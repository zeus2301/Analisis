# %%
import pandas as pd
import os
import csv
import glob
import matplotlib.pyplot as plt

# %%
mainpath = "C:/Users/marce/Python"
filename = "Analisis/Data.csv"
fullpath = os.path.join(mainpath,filename)

# %%
data = pd.read_csv(fullpath)
data.head()
# Out:
#    Tiempo  Extensión    Carga  Tiempo.1  Extensión.1  Carga.1  Tiempo.2  \
# 0     0.0    0.00000 -0.00288       0.1      0.00187 -0.00367       0.0
# 1     0.1    0.00229 -0.00118       0.2      0.00896  0.00317       0.1
# 2     0.2    0.00937  0.00647       0.3      0.01917  0.01499       0.2
# 3     0.3    0.01937  0.01917       0.4      0.02937  0.02670       0.3
# 4     0.4    0.02937  0.03354       0.5      0.03917  0.03905       0.4
#
#    Extensión.2  Carga.2  Tiempo.3  Extensión.3  Carga.3  Tiempo.4  \
# 0      0.00000 -0.00477       0.0      0.00000  0.00062       0.0
# 1      0.00271 -0.00450       0.1      0.00146  0.00133       0.1
# 2      0.00958 -0.00085       0.2      0.01062  0.00728       0.2
# 3      0.01958  0.01137       0.3      0.02187  0.01859       0.3
# 4      0.02958  0.02150       0.4      0.03187  0.02704       0.4
#
#    Extensión.4  Carga.4  Tiempo.5  Extensión.5  Carga.5
# 0      0.00000 -0.00629       0.0      0.00000 -0.00128
# 1      0.00167 -0.00644       0.1      0.00250 -0.00141
# 2      0.00833 -0.00210       0.2      0.01250  0.00668
# 3      0.01854  0.00853       0.3      0.02292  0.01729
# 4      0.02896  0.02098       0.4      0.03229  0.02927

# %%
data.describe()
# Out:
#              Tiempo     Extensión         Carga      Tiempo.1   Extensión.1  \
# count  36165.000000  37908.000000  40625.000000  40625.000000  40625.000000
# mean    1808.200000    314.050187    293.538098   1633.517948    296.189017
# std     1044.008058    749.071604    974.686064   1104.589566    726.637328
# min        0.000000      0.000000     -0.002880      0.100000      0.001870
# 25%      904.100000     78.972645      9.720820    569.700000     62.000200
# 50%     1808.200000    157.945820     21.314710   1585.300000    146.633320
# 75%     2712.300000    236.918777     35.073800   2600.900000    231.266430
# max     3616.398000   3790.758000   4062.326000   3616.500000   3790.700000
#
#             Carga.1      Tiempo.2   Extensión.2       Carga.2      Tiempo.3  \
# count  39724.000000  39724.000000  39724.000000  37908.000000  37908.000000
# mean     208.488185   1662.913589    301.748983     32.895440   1727.018115
# std      806.282123   1099.338498    733.882337     61.697093   1084.704439
# min       -0.003670      0.000000      0.000000     -0.004770      0.000000
# 25%        9.167022    637.175000     67.624155      8.921685    773.375000
# 50%       19.926455   1630.250000    150.380715     19.381965   1721.050000
# 75%       32.973515   2623.325000    233.136290     31.748970   2668.725000
# max     3972.242000   3616.400000   3790.700000    315.891630   3616.400000
#
#         Extensión.3       Carga.3      Tiempo.4   Extensión.4       Carga.4  \
# count  36623.000000  36860.000000  36860.000000  36860.000000  36623.000000
# mean     194.312224     45.959559   1776.643636    193.366078     24.000424
# std      397.218855    293.793625   1059.012478    396.114392     34.097270
# min        0.000000      0.000620      0.000000      0.000000     -0.006440
# 25%       76.296030      8.431640    851.975000     74.815038      8.287760
# 50%      152.591860     17.959280   1773.450000    151.604350     19.205000
# 75%      228.887785     29.560480   2694.925000    228.393838     32.400995
# max     3662.184000   3685.892000   3616.400000   3662.200000    305.183720
#
#            Tiempo.5   Extensión.5       Carga.5
# count  36623.000000  36165.000000  36165.000000
# mean    1786.173048    150.683446     21.161447
# std     1055.762520     87.000656     13.501177
# min        0.000000      0.000000     -0.001410
# 25%      869.750000     75.341870      8.756880
# 50%     1785.300000    150.683320     19.652810
# 75%     2700.850000    226.025390     32.780810
# max     3616.400000    301.366420     46.559040

# %%
data.dtypes
# Out:
# Tiempo         float64
# Extensión      float64
# Carga          float64
# Tiempo.1       float64
# Extensión.1    float64
# Carga.1        float64
# Tiempo.2       float64
# Extensión.2    float64
# Carga.2        float64
# Tiempo.3       float64
# Extensión.3    float64
# Carga.3        float64
# Tiempo.4       float64
# Extensión.4    float64
# Carga.4        float64
# Tiempo.5       float64
# Extensión.5    float64
# Carga.5        float64
# dtype: object

# %%
pd.isnull(data["Carga.1"]).values.ravel().sum()
# Out:
# 901

# %%
pd.notnull(data["Extensión"]).values.ravel().sum()
# Out:
# 37908

# %% [markdown]
# ### Los Valores que faltan

# %%
data1= data

# %%
data1.fillna("Desconocido")
data1.head()
# Out:
#    Tiempo  Extensión    Carga  Tiempo.1  Extensión.1  Carga.1  Tiempo.2  \
# 0     0.0    0.00000 -0.00288       0.1      0.00187 -0.00367       0.0
# 1     0.1    0.00229 -0.00118       0.2      0.00896  0.00317       0.1
# 2     0.2    0.00937  0.00647       0.3      0.01917  0.01499       0.2
# 3     0.3    0.01937  0.01917       0.4      0.02937  0.02670       0.3
# 4     0.4    0.02937  0.03354       0.5      0.03917  0.03905       0.4
#
#    Extensión.2  Carga.2  Tiempo.3  Extensión.3  Carga.3  Tiempo.4  \
# 0      0.00000 -0.00477       0.0      0.00000  0.00062       0.0
# 1      0.00271 -0.00450       0.1      0.00146  0.00133       0.1
# 2      0.00958 -0.00085       0.2      0.01062  0.00728       0.2
# 3      0.01958  0.01137       0.3      0.02187  0.01859       0.3
# 4      0.02958  0.02150       0.4      0.03187  0.02704       0.4
#
#    Extensión.4  Carga.4  Tiempo.5  Extensión.5  Carga.5
# 0      0.00000 -0.00629       0.0      0.00000 -0.00128
# 1      0.00167 -0.00644       0.1      0.00250 -0.00141
# 2      0.00833 -0.00210       0.2      0.01250  0.00668
# 3      0.01854  0.00853       0.3      0.02292  0.01729
# 4      0.02896  0.02098       0.4      0.03229  0.02927

# %%
data2= data

# %%
pd.isnull(data2["Extensión"]).values.ravel().sum()
# Out:
# 2717

# %%
data2["Extensión"].fillna(method="backfill")
# Out:
# 0        0.00000
# 1        0.00229
# 2        0.00937
# 3        0.01937
# 4        0.02937
# 5        0.03917
# 6        0.04854
# 7        0.05750
# 8        0.06625
# 9        0.07479
# 10       0.08333
# 11       0.09167
# 12       0.10000
# 13       0.10833
# 14       0.11646
# 15       0.12500
# 16       0.13333
# 17       0.14167
# 18       0.15000
# 19       0.15812
# 20       0.16646
# 21       0.17500
# 22       0.18333
# 23       0.19167
# 24       0.20000
# 25       0.20854
# 26       0.21708
# 27       0.22521
# 28       0.23333
# 29       0.24167
#           ...
# 40595        NaN
# 40596        NaN
# 40597        NaN
# 40598        NaN
# 40599        NaN
# 40600        NaN
# 40601        NaN
# 40602        NaN
# 40603        NaN
# 40604        NaN
# 40605        NaN
# 40606        NaN
# 40607        NaN
# 40608        NaN
# 40609        NaN
# 40610        NaN
# 40611        NaN
# 40612        NaN
# 40613        NaN
# 40614        NaN
# 40615        NaN
# 40616        NaN
# 40617        NaN
# 40618        NaN
# 40619        NaN
# 40620        NaN
# 40621        NaN
# 40622        NaN
# 40623        NaN
# 40624        NaN
# Name: Extensión, Length: 40625, dtype: float64

# %%
data2.head()
# Out:
#    Tiempo  Extensión    Carga  Tiempo.1  Extensión.1  Carga.1  Tiempo.2  \
# 0     0.0    0.00000 -0.00288       0.1      0.00187 -0.00367       0.0
# 1     0.1    0.00229 -0.00118       0.2      0.00896  0.00317       0.1
# 2     0.2    0.00937  0.00647       0.3      0.01917  0.01499       0.2
# 3     0.3    0.01937  0.01917       0.4      0.02937  0.02670       0.3
# 4     0.4    0.02937  0.03354       0.5      0.03917  0.03905       0.4
#
#    Extensión.2  Carga.2  Tiempo.3  Extensión.3  Carga.3  Tiempo.4  \
# 0      0.00000 -0.00477       0.0      0.00000  0.00062       0.0
# 1      0.00271 -0.00450       0.1      0.00146  0.00133       0.1
# 2      0.00958 -0.00085       0.2      0.01062  0.00728       0.2
# 3      0.01958  0.01137       0.3      0.02187  0.01859       0.3
# 4      0.02958  0.02150       0.4      0.03187  0.02704       0.4
#
#    Extensión.4  Carga.4  Tiempo.5  Extensión.5  Carga.5
# 0      0.00000 -0.00629       0.0      0.00000 -0.00128
# 1      0.00167 -0.00644       0.1      0.00250 -0.00141
# 2      0.00833 -0.00210       0.2      0.01250  0.00668
# 3      0.01854  0.00853       0.3      0.02292  0.01729
# 4      0.02896  0.02098       0.4      0.03229  0.02927

# %% [markdown]
# # Borrado de columnas de "Tiempo"

# %%
data3["Extensión"] = data3["Extensión"].fillna(method="ffill")
data3["Extensión.1"] = data3["Extensión.1"].fillna(method="ffill")
data3["Extensión.2"] = data3["Extensión.2"].fillna(method="ffill")
data3["Extensión.3"] = data3["Extensión.3"].fillna(method="ffill")
data3["Extensión.4"] = data3["Extensión.4"].fillna(method="ffill")
data3["Extensión.5"] = data3["Extensión.5"].fillna(method="ffill")
data3["Carga"] = data3["Extensión"].fillna(method="ffill")
data3["Carga.1"] = data3["Extensión.1"].fillna(method="ffill")
data3["Carga.2"] = data3["Extensión.2"].fillna(method="ffill")
data3["Carga.3"] = data3["Extensión.3"].fillna(method="ffill")
data3["Carga.4"] = data3["Extensión.4"].fillna(method="ffill")
data3["Carga.5"] = data3["Extensión.5"].fillna(method="ffill")
data3.head(460)
# Out:
#      Extensión    Carga  Extensión.1  Carga.1  Extensión.2  Carga.2  \
# 0      0.00000  0.00000      0.00187  0.00187      0.00000  0.00000
# 1      0.00229  0.00229      0.00896  0.00896      0.00271  0.00271
# 2      0.00937  0.00937      0.01917  0.01917      0.00958  0.00958
# 3      0.01937  0.01937      0.02937  0.02937      0.01958  0.01958
# 4      0.02937  0.02937      0.03917  0.03917      0.02958  0.02958
# 5      0.03917  0.03917      0.04833  0.04833      0.03979  0.03979
# 437      3.64208  3.64208      3.64187  3.64187      3.64229  3.64229
# 438      3.65062  3.65062      3.65000  3.65000      3.65042  3.65042
# 439      3.65875  3.65875      3.65854  3.65854      3.65854  3.65854
# 440      3.66667  3.66667      3.66708  3.66708      3.66667  3.66667
# 441      3.67479  3.67479      3.67542  3.67542      3.67542  3.67542
# 442      3.68396  3.68396      3.68333  3.68333      3.68375  3.68375
# 443      3.69229  3.69229      3.69146  3.69146      3.69187  3.69187
# 444      3.70021  3.70021      3.70000  3.70000      3.70000  3.70000
# 445      3.70833  3.70833      3.70875  3.70875      3.70812  3.70812
# 446      3.71667  3.71667      3.71708  3.71708      3.71687  3.71687
# 447      3.72542  3.72542      3.72521  3.72521      3.72542  3.72542
# 448      3.73417  3.73417      3.73333  3.73333      3.73354  3.73354
# 449      3.74229  3.74229      3.74187  3.74187      3.74167  3.74167
# 450      3.75021  3.75021      3.75042  3.75042      3.75000  3.75000
# 451      3.75875  3.75875      3.75875  3.75875      3.75854  3.75854
# 452      3.76708  3.76708      3.76708  3.76708      3.76708  3.76708
# 453      3.77542  3.77542      3.77521  3.77521      3.77542  3.77542
# 454      3.78375  3.78375      3.78354  3.78354      3.78333  3.78333
# 455      3.79187  3.79187      3.79187  3.79187      3.79167  3.79167
# 456      3.80021  3.80021      3.80000  3.80000      3.80021  3.80021
# 457      3.80875  3.80875      3.80833  3.80833      3.80854  3.80854
# 458      3.81708  3.81708      3.81667  3.81667      3.81667  3.81667
# 459      3.82542  3.82542      3.82500  3.82500      3.82479  3.82479
#
# [460 rows x 12 columns]

# %%
data3 =data
data3 =data3.drop(["Tiempo", "Tiempo.1", "Tiempo.2", "Tiempo.3","Tiempo.4","Tiempo.5"],axis=1)
data3.head()
# Out:
#    Extensión    Carga  Extensión.1  Carga.1  Extensión.2  Carga.2  \
# 0    0.00000 -0.00288      0.00187 -0.00367      0.00000 -0.00477
# 1    0.00229 -0.00118      0.00896  0.00317      0.00271 -0.00450
# 2    0.00937  0.00647      0.01917  0.01499      0.00958 -0.00085
# 3    0.01937  0.01917      0.02937  0.02670      0.01958  0.01137
# 4    0.02937  0.03354      0.03917  0.03905      0.02958  0.02150
#
#    Extensión.3  Carga.3  Extensión.4  Carga.4  Extensión.5  Carga.5
# 0      0.00000  0.00062      0.00000 -0.00629      0.00000 -0.00128
# 1      0.00146  0.00133      0.00167 -0.00644      0.00250 -0.00141
# 2      0.01062  0.00728      0.00833 -0.00210      0.01250  0.00668
# 3      0.02187  0.01859      0.01854  0.00853      0.02292  0.01729
# 4      0.03187  0.02704      0.02896  0.02098      0.03229  0.02927

# %%
pd.isnull(data3["Extensión.5"]).values.ravel().sum()
# Out:
# 4460

# %% [markdown]
# # Plot y visualización

# %%
matplotlib inline

# %%
#Scatter plot

# %%
data4 = data3
data4.plot(kind="scatter", x ="Extensión", y="Carga")

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
data4.plot(kind="line", x ="Extensión.3", y="Carga.3", ax=axs[0][0])

# %%
Carga= data4["Carga"]
Carga.head()
# Out:
# 0   -0.00288
# 1   -0.00118
# 2    0.00647
# 3    0.01917
# 4    0.03354
# Name: Carga, dtype: float64
