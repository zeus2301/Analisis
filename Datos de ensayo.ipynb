# %%
import pandas as pd
import os
import csv

# %%
mainpath = "C:/Users/marce/Caracterizacion/Traccion 2019/"
filename = "Probeta.5-6-7"
fullpath = os.path.join(mainpath,fullpath)

# %%
data = pd.read_csv(fullpath)
data.head(60)
# Out:
#                         Deformacin : Hora de retirada   Unnamed: 1      s
# 0   Elongacin tras la fractura : Elongacin tras la...          NaN      %
# 1   Elongacin tras la fractura : Nmero de estadoal...           24    NaN
# 2   Elongacin tras la fractura : Separacin de marc...          NaN     mm
# 3   Elongacin tras la fractura : Separacin de marc...          NaN     mm
# 4               Ensayo : Velocidad 1,"5.00000",mm/min          NaN    NaN
# 5   Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# 6   Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# 7   Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# 8   Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# 9   Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# 10  Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# 11  Entrada de opcin de la probeta : Entrada de op...    <Ninguno>    NaN
# ...

# %%
cols = data.readline().stip().slit(",")
cols

# %%
csvarchivo = open('final.csv')  # Abrir archivo csv
entrada = csv.reader(csvarchivo)  # Leer todos los registros
reg = next(entrada)  # Leer registro (lista)
print(reg)  # Mostrar registro

# %%
data_cols = pd.read_csv(fullpath)
data_col_list = data_cols["Column_Names"].tolist()
data2 = pd.read_csv(mainpath + "/" + "Probeta.5-6-7/final.csv", 
                    header = None, names = data_col_list)
data2.columns.values
